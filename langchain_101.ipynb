# %% [markdown]
# # LangChain 101
# I'm going to slowly build up my runnables to be a chain, to perform basic RAG functionality.
#
# Stack:
# - LLM: Ollama (llama3.1)
# - Vector Store: Chroma
# - UI: Streamlit
# - Memory: SQLite
# - Embeddings: BGE or all-MiniLM-L6-v2

# %% [markdown]
# Enable LangSmith tracing by setting up the `.env` file.

# %%
from dotenv import load_dotenv
load_dotenv("../.env", override=True)
# Out:
# False

# %% [markdown]
# ## LLM response

# %%
from langchain_ollama import ChatOllama
llm = ChatOllama(model="llama3.1", temperature=0)

# %%
result = llm.invoke("What is LangChain?")

# %%
from rich.markdown import Markdown
Markdown(result.content)
# Out:
# LangChain is an open-source framework for building conversational AI applications. It's designed to make it easier
# to create and integrate large language models (LLMs) into various use cases, such as chatbots, virtual assistants,
# and more.
#
# LangChain provides a set of tools and libraries that enable developers to:
#
#  1 Load and manage LLMs: LangChain supports popular LLMs like BERT, RoBERTa, and others, making it easy to
#    integrate them into applications.
#  2 Create conversational flows: Developers can define conversational workflows using a simple, declarative syntax,
#    which allows for more flexibility and ease of use.
#  3 Integrate with external data sources: LangChain enables seamless integration with various data sources, such as
#    databases, APIs, or even other AI models.
#  4 Manage context and state: The framework provides features to manage conversation context and state, ensuring
#    that the conversational flow is consistent and accurate.
#
# Some of the key benefits of using LangChain include:
#
#  • Simplified development process: LangChain abstracts away many complexities associated with building
#    conversational AI applications, making it easier for developers to focus on the application logic.
#  • Improved scalability: The framework is designed to handle large volumes of conversations and data, making it
#    suitable for production environments.
#  • Flexibility and customizability: LangChain's modular architecture allows developers to easily integrate new
#    features or models as needed.
#
# LangChain has gained popularity in recent times due to its ease of use, flexibility, and the ability to support a
# wide range of LLMs. If you're interested in building conversational AI applications, LangChain is definitely worth
# exploring!

# %% [markdown]
# ## SQLite

# %% [markdown]
# ## Chroma
